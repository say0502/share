# %%
import requests,json
import numpy as np
from pprint import pprint

url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=台灣.台南.中西區.餐廳&language=zh-TW&key=AIzaSyBRWcGp4lAOw7HxaU6-mU8xllv9hLPCFxo&pageToken=[NEXT PAGE TOKEN GOES HERE]'
response = requests.get(url)
jsonDict = json.loads(response.text)
pprint(jsonDict)
#for i in ((jsonDict['results'])):
    #[i]['opening_hours'] = str([0]['opening_hours'])

#result = jsonDict['opening_hours']
#print(np.array(jsonDict)[14])
#np.shape(x)
#type(data)
#type(jsonDict)

#data_json['opening_hours'] = str(data_json['opening_hours'])
#print(data.text)
#print(content)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBv_LA3pqGuqGtsBmA7JTMcSMqKaMPIM34z3DEyW580HK-aMkAFFfrntanoNvWGVDCyI-WCXHMDok0nvVKItIhErMf8sLT6qhz6KTI3xkVr6eCcP9NGtt3pbob0vHbNs1gSxJe-w9yke5bGFxrBjC26df1FEQFbMCbPa2NIMOzhXGR9bEnJUKKMod9de93vkRwY4RTtW3WlEovVNf0SduXOnRygAyn_auNSsVBYncJGcyrwGCX8ZeijPL6n1RIUDvGEm38O7FFLMptsNVdPsT9L0KyY8BKCLsmUXz8eriARi5pe9qTel3c_6_xlLR7BwptVmqn_-m9CVMncRFxcDb2xQGLzqCAH-EaZ6KRhVgMDJwPO5_mvJQ8y73bAvp3aVq6W6rZiNARa28lCM2F31stEOcz42M_Nf58uZQ',
#  'results': [{'business_status': 'OPERATIONAL',
#               'formatted_address': '700台灣台南市中西區府前路一段68號',
#               'geometry': {'location': {'lat': 22.9891102, 'lng': 120.2093811},
#                            'viewport': {'northeast': {'lat': 22.99037097989272,
#                                                       'lng': 120.2107305298927},
#                                         'southwest': {'lat': 22.98767132010727,
# ...

# %%
import requests,json
import numpy as np
from pprint import pprint
url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?page_token=Aap_uECuZJBFGHL0_SsbksYvhP3tbreWodiMn_UH8sWetR3bNC31GWw6IZPuqchM1UcIfCQvoHLRkD-a22nrDz4SazPsTIU5SAdK-R47hUX3uNGKjvIsct35twWHbM4SUTeA4yfYy_L6f4slZJUS6AHAhbn8sa_-3eViR9AW3EGP2bEEl7509AKJxmqd3fgIFCOfPahRDail-NJJuj0eSwBoMhgORgV7LuPLk53ML8RHqSXzkCxfLMEbwe6RtC9skAPwNnKYwtZ2Z4zRRggcfL6kFdiFOf3z0fMV4DuCu49NdtxugUGCstr7gZuGGSYpEfIXG9pRpOlCFEJf1Py1f41LfTctOkHN5sNpp-NZkySJMGxgAie-tbaLuhTzNLhkG81cGGNyRcNvxqsYmOo1BDl-f_X3_rqhBJlg6sowCQ&key=AIzaSyBRWcGp4lAOw7HxaU6-mU8xllv9hLPCFxo'
response = requests.get(url)
jsonDict = json.loads(response.text)
pprint(jsonDict)
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}

# %% [markdown]
# ## GOOGLE api 區域餐廳獲取

# %%
import requests,json
import numpy as np
from pprint import pprint
import time
x = []
url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=台灣.台南.中西區.餐廳&language=zh-TW&key=AIzaSyBhQG34Xc5m-Qc6Sf68uEl5GorCQUB-YW0&pageToken=[NEXT PAGE TOKEN GOES HERE]'
response = requests.get(url)
jasonDict = json.loads(response.text)
i = jasonDict['next_page_token']
del jasonDict['html_attributions']
del jasonDict['next_page_token']

time.sleep(5)
  
url1 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken='+i+'&key=AIzaSyBhQG34Xc5m-Qc6Sf68uEl5GorCQUB-YW0'
response = requests.get(url1)
jasonDict = json.loads(response.text)
# print(jasonDict)
s = jasonDict['next_page_token']
del jasonDict['html_attributions']
del jasonDict['next_page_token']
x.append(jasonDict)
time.sleep(10)
    
url2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken='+s+'&key=AIzaSyBhQG34Xc5m-Qc6Sf68uEl5GorCQUB-YW0'
response = requests.get(url2)
jasonDict = json.loads(response.text)
# i = jasonDict['next_page_token']
del jasonDict['html_attributions']
x.append(jasonDict)
time.sleep(5)

# %%
import pandas as pd

test = pd.DataFrame(x[0]['results'])
test
# Out:
#    business_status        formatted_address  \
# 0      OPERATIONAL     700台灣台南市中西區中正路199巷5號
# 1      OPERATIONAL       700台灣台南市中西區和意路1號1樓
# 2      OPERATIONAL     700台灣台南市中西區民生路二段120號
# 3      OPERATIONAL      700台灣台南市中西區海安路一段66號
# 4      OPERATIONAL     700台灣台南市中西區永福路一段269號
# 5      OPERATIONAL  700台灣台南市中西區西門路二段300巷27號
# 6      OPERATIONAL     700台灣台南市中西區信義街108巷1號
# 7      OPERATIONAL        700台灣台南市中西區觀亭街39號
# 8      OPERATIONAL     700台灣台南市中西區海安路一段107號
# 9      OPERATIONAL     700台灣台南市中西區國華街二段156號
# 10     OPERATIONAL     700台灣台南市中西區府前路一段124號
# 11     OPERATIONAL    700台灣台南市中西區民族路三段19-2號
# 12     OPERATIONAL       700台灣台南市中西區中正路376號
# 13     OPERATIONAL    700台灣台南市中西區友愛街213號之2號
# 14     OPERATIONAL     700台灣台南市中西區民權路三段364號
# 15     OPERATIONAL  700台灣台南市中西區西門路二段372巷10號
# 16     OPERATIONAL        700台灣台南市中西區新美街20號
# 17     OPERATIONAL        700台灣台南市中西區新美街54號
# 18     OPERATIONAL   700台灣台南市中西區西和路26號 號 No
# 19     OPERATIONAL         700台灣台南市中西區成功路1號
#
# ...

# %% [markdown]
# ## json檔轉dataFrame

# %%
import pandas as pd
# data1 = pd.DataFrame(x[0]['results'])
lat_data=[]
lng_data=[]
for j in range(len(x)):
    for i in range(20):
        lat = x[j]['results'][i]['geometry']['location']['lat']
        lng = x[j]['results'][i]['geometry']['location']['lng']
        address = x[j]['results'][i]['formatted_address']
        name = x[j]['results'][i]['name']
        photo = x[j]['results'][i]['photos'][0]['html_attributions']
        rating = x[j]['results'][i]['rating']
        user_ratings_total = x[j]['results'][i]['user_ratings_total']
        lat_data.append(lat)
        lng_data.append(lng)
    
    
    
    

data = pd.DataFrame([lat_data,lng_data],index=['經度','緯度'])
data.T
# Out:
#            經度          緯度
# 0   22.992563  120.197943
# 1   22.987620  120.199253
# 2   22.995585  120.196085
# 3   22.988978  120.195254
# 4   22.988964  120.199990
# 5   22.996651  120.200370
# 6   23.000677  120.194764
# 7   22.997204  120.205660
# 8   22.990222  120.195092
# 9   22.991431  120.197012
# 10  22.988984  120.208024
# 11  22.997739  120.198904
# 12  22.994084  120.193579
# 13  22.991895  120.197164
# 14  22.998690  120.189633
# 15  22.998030  120.201033
# 16  22.994625  120.200209
# 17  22.995075  120.200380
# 18  22.999197  120.187856
# 19  22.997167  120.210648
# 20  22.997203  120.204281
# 21  22.995140  120.196226
# 22  22.999542  120.196186
# 23  22.995502  120.196887
# 24  22.995907  120.197181
# 25  22.993145  120.206882
# 26  22.989835  120.193307
# 27  22.994746  120.204106
# 28  22.994339  120.197502
# 29  22.994087  120.203681
# 30  22.992387  120.210777
# 31  22.991693  120.195093
# 32  22.994258  120.205004
# 33  22.998363  120.196959
# ...

# %% [markdown]
# ## 資料庫匯入

# %%
import pymssql

# %%
conn = pymssql.connect(server='localhost',
                      user='sa',
                      password='aq1023695',
                      database='美食地圖')
cursor = conn.cursor()

if not cursor:
    raise Exception('資料庫連線失敗')

# %%
# 將 python 資料轉成 json 格式
data = json.dumps(x)
print(data)

# 將 python 資料儲存成 json 檔案
file = open('中西區.json', 'w', encoding='utf8')
json.dump(x, file, ensure_ascii=False)
file.close()

# %%
# 讀取 json 檔案入資料庫
with open('中西區.json', 'r', encoding='utf8') as file:
    dictTemp = json.load(file)
    
cursor = conn.cursor()  
try:
    sql = "INSERT INTO dbo.EMPLOYEE(ID, FIRSTNAME, LASTNAME, BIRTHDAY, SALARY) VALUES(%d, %s, %s, %s, %d)"
    for row in dictTemp:
        print(row)
        data = tuple(row.values())
        cursor.execute(sql, data)   
    conn.commit()
    
except Exception as e:
    print('Error:', e)
finally:
    cursor.close()

# %%
df5.to_csv('中西區60.csv', encoding='utf8', index=False)

# %%
url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken=Aap_uEB_prnzR7gvXOVy5QcB5kW5W6ZqLiPI35RLe9YpORRwCJSpgepV0JGjaND6UVWVjGziF39WZlJvfG-ZwCEEJ263G6bmFz6nKeqa9ZeztQaQuiHmzZYu3CSKNM8IO0zkRjzl5koZI-ZXOrXQuXKAyjwvRuAqOxEyNtaMxW2lCFJcxN4FeKHFuYmnWE755R7eTIwDt4DQUgoPDVZl_IJtlNQtiIHq39xqq-GYomZO-QqzKc4_SLE2LCqze8bQPWJJw325MPWTnx8lGnLxKy2vakAhM2r4XhdvVkXz-GrZTZsQ_QGov8lJPkgYdzspKQG9eD0IGX_ce5HkL4JI_EuLn3XXXI-nS73l0_lGyu4vAE_BvqhptZ7yM5se35AJ1TXC0q4xV6Mk2iCVga2M3vkg2oQhXknH6nSv6dUElg&key=AIzaSyBhQG34Xc5m-Qc6Sf68uEl5GorCQUB-YW0'
data = requests.get(url)
data_json = data.json()
data_json

# %%
url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken=Aap_uECRDSlEtLPwfuePCLjStjTdRZGFzKFYo_I8vNliW_TXEOrNVYHyee0DrJyendIuQCU5Pv2zWWZJAoZVe5t2HCo5lleXj1t9IQXJsAlRkZkU8pQYu1FrofuscGzlZoArRanIgGuGZ9HyrZLW1zB_2s3Ao4Adkm7-NpdlvYHOsAlIAjs2KwesyvNslbbfxs6L3MaX7z0v-ilZBEvgH17FifPGx3An7g46XAxVgFFbx0LBIfs40p8coNkCcC3A6RyfiA1wicWB2NyDdFMqDWdTTwetJdcTgyEsDIYGIOl2OnpIUU8ot1fqYNTTSqE4MrXfn1fGi67Up_ncZKBZhw52rHVUcLHNSpK-p2YqJ_z5HA_sQKul1kAcFRAUI6zsHxChDtw-yUPYeLp9-DiYlvdehfVIznnCGjWtPycgrvHT6ELH5sUv5RicTgh13dWH9zChUfR7ERj5I-L5RWXNOI3smTc_DDOLJoOeeAPMTI1sGMExfWoCf5BeVgC9bw09vtYLOSBURH8SJ2mxyPGIRfaZcuScPQaNreHEJRuVVhTXcbLSQHl5IeYyVg_6zhob650zTHRZPeMCF7K2ihiE5sbfATnWwM8MdcaEmkNu3jD30JE09xiwc1StsxxxbOM&key=AIzaSyBhQG34Xc5m-Qc6Sf68uEl5GorCQUB-YW0'
data = requests.get(url)
data_json = data.json()
data_json
